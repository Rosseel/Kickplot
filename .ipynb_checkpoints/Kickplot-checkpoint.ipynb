# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
df=pd.read_csv('ks_2018.csv')
df.head()
df.shape
# Out:
# (378661, 15)

# %%
# print(df.state.value_counts())
shape_map = {"failed":"x", "successful":"v", "canceled":"x", "undefined":"x", "live":"x", "suspended":"x"}
color_map = {"failed":"red", "successful":"blue", "canceled":"red", "undefined":"red", "live":"red", "suspended":"red"}

df['shapes']= df.state.map(shape_map)
df['color']= df.state.map(color_map)


converted_deadline = pd.to_datetime(df.deadline)
converted_launched_date=pd.to_datetime(df.launched)
df['days_between']=converted_deadline-converted_launched_date
# x=df.deadline-df.launched
# x




plt.scatter(df.days_between,df.pledged , marker=df.shapes, c=df.color)
# Out:
# <class 'tuple'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     288             try:
# --> 289                 Path(marker)
#     290                 self._marker_function = self._set_vertices
#
# ~/.local/lib/python3.8/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     126         """
# --> 127         vertices = _to_unmasked_float_array(vertices)
#     128         if vertices.ndim != 2 or vertices.shape[1] != 2:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1316     else:
# -> 1317         return np.asarray(x, float)
#    1318
#
# ~/.local/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#
# ValueError: could not convert string to float: 'x'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-82fabcc29dec> in <module>
#      16
#      17
# ---> 18 plt.scatter(tuple(df.days_between),tuple(df.pledged) , marker=tuple(df.shapes), c=tuple(df.color))
#      19
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4410             marker_obj = marker
#    4411         else:
# -> 4412             marker_obj = mmarkers.MarkerStyle(marker)
#    4413
#    4414         path = marker_obj.get_path().transformed(
#
# ~/.local/lib/python3.8/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     223         self._marker_function = None
#     224         self.set_fillstyle(fillstyle)
# --> 225         self.set_marker(marker)
#     226
#     227     def _recache(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     290                 self._marker_function = self._set_vertices
#     291             except ValueError:
# --> 292                 raise ValueError('Unrecognized marker style {!r}'
#     293                                  .format(marker))
#     294
#
# ValueError: Unrecognized marker style ('x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'o', 'o', 'x', 'o', 'o', 'x', 'o', 'x', 'o', 'o', 'x', 'o', 'x', 'o', 'o', 'x', 'o', 'x', 'o', 'o', 'o', 'x', 'o', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'o', 'o', 'o', 'o', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'o', 'x', 'x', 'o', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'o', 'o', 'x', 'o', 'o', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'o', 'o', 'o', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'o', 'o', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'o', 'x', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'o', 'o', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'o', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'o', 'o', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'o', 'x', 'o', 'o', 'x', 'o', 'o', 'x', 'o', 'o', 'o', 'x', 'x', 'o', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'o', 'o', 'x', 'x', 'o', 'o', 'x', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'o', 'o', 'x', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'o', 'x', 'x', 'o', 'x', 'o', 'o', 'x', 'o', 'x', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'o', 'o', 'o', 'o', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'o', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'x', 'x', 'o', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'o', 'x', 'o', 'x', 'o', 'x', 'o', 'x', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'o', 'o', 'o', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'x', 'o', 'o', 'o', 'x', 'o', 'x', 'x', 'o', 'o', 'o', 'x', 'o', 'o', 'x', 'x', 'o', 'x', 'x', 'x', 'x', 'o', 'x', ' ...

# %%
number_of_records=df.shape[0]
vc=df.main_category.value_counts()
vc_in_percentages=vc/number_of_records

#the sections that are smaller than 
smaller_section= vc_in_percentages[vc_in_percentages<0.03]
vc_in_percentages= vc_in_percentages[vc_in_percentages>=0.03]

vc_in_percentages.items()

keywords,percentages=zip(*vc_in_percentages.items())
keywords=list(keywords)
percentages=list(percentages)
keywords.append('Varia')
percentages.append(smaller_section.sum())
        

fig1, ax1 = plt.subplots()
ax1.pie(percentages, labels=keywords, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
